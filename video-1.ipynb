# %%
import qiskit
import qiskit_ibm_runtime

# %%
print(qiskit.__version__)
print(qiskit_ibm_runtime.__version__)
# Out:
# 2.4.1
# 0.47.0

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(
    channel="ibm_quantum_platform",
    token="HtdfUjK9Hd26Jdv97X9XlHFumYlvsJPia0cUQTmqNzot",
)
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-05-23 18:00:57,883: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-05-23 18:01:06,407: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().

# %%
print(service.backends())
# Out:
# qiskit_runtime_service.backends:WARNING:2026-05-23 18:02:35,538: Loading instance: open-instance, plan: open
# [<IBMBackend('ibm_kingston')>, <IBMBackend('ibm_marrakesh')>, <IBMBackend('ibm_fez')>]

# %%
QiskitRuntimeService.save_account(
    channel="ibm_quantum_platform",
    token="HtdfUjK9Hd26Jdv97X9XlHFumYlvsJPia0cUQTmqNzot"
)

# %%
for backend in service.backends():
    print(backend.name)
# Out:
# qiskit_runtime_service.backends:WARNING:2026-05-23 18:23:33,421: Loading instance: open-instance, plan: open
# ibm_kingston
# ibm_marrakesh
# ibm_fez

# %%
backend = service.backend(name="ibm_fez")
# Out:
# qiskit_runtime_service.backends:WARNING:2026-05-23 18:23:56,458: Using instance: open-instance, plan: open

# %%
backend.num_qubits
# Out:
# 156
